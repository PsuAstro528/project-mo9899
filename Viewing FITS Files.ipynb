# %%
from astropy.io import fits

# %%
fits_image_filename = fits.util.get_testdata_filepath('Sample Solar Dataset.fits')

hdul = fits.open(fits_image_filename)
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16332/3438073830.py in <module>
# ----> 1 fits_image_filename = fits.util.get_testdata_filepath('Sample Solar Dataset.fits')
#       2
#       3 hdul = fits.open(fits_image_filename)
#
# c:\users\yadav\appdata\local\programs\python\python39\lib\site-packages\astropy\io\fits\util.py in get_testdata_filepath(filename)
#     883         The path to the requested file.
#     884     """
# --> 885     return data.get_pkg_data_filename(
#     886         f'io/fits/tests/data/{filename}', 'astropy')
#     887
#
# c:\users\yadav\appdata\local\programs\python\python39\lib\site-packages\astropy\utils\data.py in get_pkg_data_filename(data_name, package, show_progress, remote_timeout)
#     643             return datafn
#     644         else:  # remote file
# ...
